# %%
import os
from matplotlib import pyplot
import pandas as pd

print (os.getcwd())

data_file = os.path.join('data', 'data.csv')
results_df = pd.read_csv(data_file)
xdata = results_df['x'] # extracting the x values
ydata = results_df['val'] # extracting the measurement values
pyplot.scatter(xdata, ydata)
pyplot.title("Sample4")
pyplot.xlabel("x")
pyplot.ylabel("Val")
# Out:
# /home/tifigo/python_MTLS/Ch8_exercises
# Text(0, 0.5, 'Val')
